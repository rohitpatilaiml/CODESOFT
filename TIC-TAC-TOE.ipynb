# %% [markdown]
# # **TIC-TAC-TOE AI**

# %%
# Out:
# Tic-Tac-Toe Game Designed By Sourabh Somani
# Player 1 [X] --- Player 2 [O]
#
#
#
# Please Wait...
#    |   |
# ___|___|___
#    |   |
# ___|___|___
#    |   |
#  | |
# Player 1's chance
# Enter the position between [1-9] where you want to mark: 1
#  X |   |
# ___|___|___
#    |   |
# ___|___|___
#    |   |
#  | |
#  X |   |
# ___|___|___
#    |   |
# ___|___|___
#    |   |
#  | |
# Player 2's chance
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-2e645cae1cfc> in <cell line: 67>()
#      76         Mark = 'O'
#      77
# ---> 78     choice = int(input("Enter the position between [1-9] where you want to mark: "))
#      79     if CheckPosition(choice):
#      80         board[choice] = Mark
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
# ...
